# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarav2123/python-basics/blob/main/WEEK1_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def dc_circuit_analyzer():
  V=float(input("What is value of voltage(Volts): "))
  R=float(input("What is value of resistance(Ohm): "))

  if R<=0:
    print ("Resistance can not be zero or negative")

  else :
    I=V/R
    print(f"The current flowing is {I:.2f} Amperes")

    P=V**2/R
    print(f"The power dissipated is {P:.2f} Watts")

dc_circuit_analyzer()
# Out:
# What is value of voltage(Volts): 22
# What is value of resistance(Ohm): 11
# The current flowing is 2.00 Amperes
# The power of electricity is 44.00 Watts
